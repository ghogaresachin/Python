# %%
int(True)
# Out:
# 1

# %%
import numpy as np,pandas as pd,seaborn as sns
import matplotlib.pyplot as plt

# %%
pokemon=pd.read_csv("C:\python\Data\Pokemon.csv")
pokemon.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
type((pokemon['Legendary'][0]))
# Out:
# numpy.bool_

# %% [markdown]
# ### Changing data types of a particular data frame

# %%
data=pokemon.astype({"Legendary":int})       
data.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1          0
# 1       80       80     60           1          0
# 2      100      100     80           1          0
# 3      122      120     80           1          0
# 4       60       50     65           1          0

# %%
a=sns.lmplot(x='Total',y='Speed',data=pokemon,aspect =2)
a=(a.set_axis_labels('TOTAL','SPEED')).set(xlim=(0,1000),ylim=(0,200))
#a.set_xticklabels(rotation=90)
#a.set_yticklabels(rotation=90)

# %% [markdown]
# Plotting with seaborn

# %%
data=pd.DataFrame({'x':np.arange(1,101),
                   'y':np.random.normal(0,4,100)})
data
# Out:
#       x         y
# 0     1 -0.275655
# 1     2  0.978309
# 2     3 -0.590983
# 3     4  6.114161
# 4     5 -3.746774
# ..  ...       ...
# 95   96  8.196118
# 96   97 -0.561073
# 97   98 -1.901074
# 98   99 -0.688934
# 99  100  5.343681
#
# [100 rows x 2 columns]

# %%
sns.set()
sns.set_style('whitegrid')
sns.set_style('ticks',{'xtick.major.size':8,'ytick.major.size':8})
sns.axes_style('whitegrid')
# Out:
# {'figure.facecolor': 'white',
#  'axes.labelcolor': '.15',
#  'xtick.direction': 'out',
#  'ytick.direction': 'out',
#  'xtick.color': '.15',
#  'ytick.color': '.15',
#  'axes.axisbelow': True,
#  'grid.linestyle': '-',
#  'text.color': '.15',
#  'font.family': ['sans-serif'],
#  'font.sans-serif': ['Arial',
#   'DejaVu Sans',
#   'Liberation Sans',
#   'Bitstream Vera Sans',
#   'sans-serif'],
#  'lines.solid_capstyle': 'round',
#  'patch.edgecolor': 'w',
#  'patch.force_edgecolor': True,
#  'image.cmap': 'rocket',
#  'xtick.top': False,
#  'ytick.right': False,
#  'axes.grid': True,
#  'axes.facecolor': 'white',
#  'axes.edgecolor': '.8',
#  'grid.color': '.8',
#  'axes.spines.left': True,
#  'axes.spines.bottom': True,
#  'axes.spines.right': True,
#  'axes.spines.top': True,
#  'xtick.bottom': False,
#  'ytick.left': False}

# %% [markdown]
# Plotting with seaborn

# %%
a=sns.factorplot(x='Total',y='Speed',data=pokemon,aspect=2)      #Subplot grid for relation between variables
a.set_xticklabels(rotation=180)
# Out:
# C:\Users\sachi\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# Plot Regression model

# %%
sns.lmplot(x='Total',y='Speed',data=pokemon)         #Plot data and fit regression line

# %% [markdown]
# Subplot grid for plotting pairwise relationships

# %%
b=sns.PairGrid(pokemon)     # Subplot grid for plotting pairwise relationships
b=b.map(plt.scatter)

# %% [markdown]
# Plot pairwise bivariate distributions

# %%
sns.pairplot(pokemon,kind='scatter',diag_kind='auto')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\lib\histograms.py:351, in _unsigned_subtract(a, b)
#     350 try:
# --> 351     dt = signed_to_unsigned[dt.type]
#     352 except KeyError:
#
# KeyError: <class 'numpy.bool_'>
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Input In [38], in <module>
# ----> 1 sns.pairplot(pokemon,kind='scatter',diag_kind='auto')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
# ...

# %%
c=sns.JointGrid(x='Total',y='Speed',data=pokemon)           #Grid for bivariate plot with marginal univariate plots
c=c.plot(sns.regplot,sns.distplot)
# Out:
# C:\Users\sachi\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\sachi\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# Plotttig Bivariate Distribution

# %%
sns.jointplot('Total','Speed',data=pokemon,kind='reg')       #Plot bivariate distributioin .... There are various types of kind some of them are 'hex','kde'
# Out:
# C:\Users\sachi\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Pairwise Plot

# %%
sns.pairplot(pokemon,kind='scatter',hue='Legendary')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Regression plots

# %%
sns.regplot(x='Total',y='Speed',data=pokemon)
# Out:
# <AxesSubplot:xlabel='Total', ylabel='Speed'>

# %% [markdown]
# Distribution Plot

# %%
sns.distplot(data.y,kde=False,color='black')
# Out:
# C:\Users\sachi\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='y'>

# %% [markdown]
# Matrix plot

# %%
uniform_data=np.random.rand(5,10)
sns.heatmap(uniform_data,vmin=0,vmax=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Scatterplot

# %%
sns.stripplot(x='Total',y='Defense',data=pokemon)
# Out:
# <AxesSubplot:xlabel='Total', ylabel='Defense'>

# %%
sns.swarmplot(x='Total',y='Type 1',data=pokemon)   # Categorical scatterplot with one categorical variable
# Out:
# C:\Users\sachi\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 40.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\sachi\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 44.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\sachi\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 48.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\sachi\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 44.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
# ...

# %% [markdown]
# Bar plot

# %%
sns.barplot(x='Legendary',y='Total',data=pokemon)
# Out:
# <AxesSubplot:xlabel='Legendary', ylabel='Total'>

# %% [markdown]
# Count plot

# %%
sns.countplot(x='Legendary',data=pokemon,palette='Reds_d')       # Count of observations
# Out:
# <AxesSubplot:xlabel='Legendary', ylabel='count'>

# %% [markdown]
# #### Boxplot

# %%
sns.boxplot('Legendary','Total',data=pokemon)
# Out:
# C:\Users\sachi\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Legendary', ylabel='Total'>

# %%
sns.boxplot(data=pokemon)
# Out:
# <AxesSubplot:>

# %%
sns.violinplot(x='Total',y='Type 1',data=pokemon,palette='rainbow')
# Out:
# <AxesSubplot:xlabel='Total', ylabel='Type 1'>
