# %% [markdown]
# Pip freeze command tells you which modules you have installed with pip install and
# the versions of these modules that you are currently have installed on your computer.

# %%
import warnings
import sys
import pandas as pd
import numpy as np

# %%
pip freeze requirement.txt
# Out:
# argon2-cffi==21.3.0
# argon2-cffi-bindings==21.2.0
# asttokens==2.0.5
# attrs==21.4.0
# backcall==0.2.0
# black==22.1.0
# bleach==4.1.0
# cffi==1.15.0
# click==8.0.3
# cmp==0.0.1
# colorama==0.4.4
# cycler==0.11.0
# data==0.4
# debugpy==1.5.1
# decorator==5.1.1
# defusedxml==0.7.1
# docopt==0.6.2
# entrypoints==0.4
# enum34==1.1.10
# et-xmlfile==1.1.0
# executing==0.8.2
# files==1.1.1
# fonttools==4.29.1
# frame==0.3.1
# fsspec==2022.5.0
# funcsigs==1.0.2
# graphviz==0.20
# ipykernel==6.8.0
# ipython==8.0.1
# ipython-genutils==0.2.0
# ipywidgets==7.6.5
# jedi==0.18.1
# Jinja2==3.0.3
# joblib==1.1.0
# jsonschema==4.4.0
# jupyter==1.0.0
# jupyter-client==7.1.2
# jupyter-console==6.4.0
# jupyter-contrib-core==0.3.3
# jupyter-contrib-nbextensions==0.5.1
# jupyter-core==4.9.1
# jupyter-highlight-selected-word==0.2.0
# jupyter-latex-envs==1.4.6
# jupyter-nbextensions-configurator==0.4.1
# jupyterlab-pygments==0.1.2
# jupyterlab-widgets==1.0.2
# kiwisolver==1.3.2
# lxml==4.7.1
# MarkupSafe==2.0.1
# matplotlib==3.5.1
# matplotlib-inline==0.1.3
# mistune==0.8.4
# modin==0.15.2
# mpmath==1.2.1
# multipart==0.2.4
# mypy-extensions==0.4.3
# mysql-connector-python==8.0.29
# nbclient==0.5.10
# nbconvert==6.4.1
# nbformat==5.1.3
# nbmerge==0.0.4
# nest-asyncio==1.5.4
# notebook==6.4.8
# numpy==1.22.2
# openpyxl==3.0.9
# packaging==21.3
# pandas==1.4.3
# pandocfilters==1.5.0
# parso==0.8.3
# pathspec==0.9.0
# patsy==0.5.2
# pickleshare==0.7.5
# Pillow==9.0.1
# platformdirs==2.4.1
# playsound==1.3.0
# prometheus-client==0.13.1
# prompt-toolkit==3.0.26
# psutil==5.9.1
# pure-eval==0.2.2
# pycparser==2.21
# pyforest==1.1.0
# Pygments==2.11.2
# pyparsing==3.0.7
# PyPDF2==1.26.0
# pyrsistent==0.18.1
# python-dateutil==2.8.2
# pytz==2021.3
# pywin32==303
# pywinpty==2.0.2
# PyYAML==6.0
# pyzmq==22.3.0
# qtconsole==5.2.2
# QtPy==2.0.1
# read==0.0.2
# repoze.lru==0.7
# rise==5.7.1
# Routes==2.5.1
# scikit-learn==1.0.2
# scipy==1.8.0
# seaborn==0.11.2
# Send2Trash==1.8.0
# six==1.16.0
# sklearn==0.0
# stack-data==0.1.4
# stats==0.1.2a0
# statsmodels==0.13.2
# stemgraphic==0.9.1
# sympy==1.9
# terminado==0.13.1
# testpath==0.5.0
# threadpoolctl==3.1.0
# toml==0.10.2
# tomli==2.0.0
# tornado==6.1
# traitlets==5.1.1
# vulture==2.5
# wcwidth==0.2.5
# webencodings==0.5.1
# widgetsnbextension==3.5.2
# Note: you may need to restart the kernel to use updated packages.
